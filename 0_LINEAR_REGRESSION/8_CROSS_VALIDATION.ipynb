# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('mpg')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.shape
# Out:
# (398, 9)

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
value = df['horsepower'].median() # since we haven't did outlier treatement

# %%
df['horsepower'].fillna(value , inplace = True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
df['origin'].value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
df['origin'].replace(['usa','japan','europe'] , ['1','2','3'], inplace = True)

# %%
df['origin'].value_counts()
# Out:
# origin
# 1    249
# 2     79
# 3     70
# Name: count, dtype: int64

# %%
df['origin'] = df['origin'].astype(int)

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int32
# name             object
# dtype: object

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
df.drop('name', axis = 1 , inplace = True)

# %%
df.shape
# Out:
# (398, 8)

# %%
x = df.drop('mpg' , axis = 1)
y = df['mpg']

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
model.coef_
# Out:
# array([-2.66313270e-01,  1.81203356e-02, -4.90767199e-05, -7.50893773e-03,
#         1.36380304e-01,  7.72753986e-01,  1.55369576e+00])

# %%
for i , col in enumerate(x_train.columns):
    print(f"for {col} the coefficient value is {model.coef_[i]:.5f}")
# Out:
# for cylinders the coefficient value is -0.26631
# for displacement the coefficient value is 0.01812
# for horsepower the coefficient value is -0.00005
# for weight the coefficient value is -0.00751
# for acceleration the coefficient value is 0.13638
# for model_year the coefficient value is 0.77275
# for origin the coefficient value is 1.55370

# %%
print(f"the train accuracy of our model is : {model.score(x_test,y_test)*100:.2f}%")
y_pred = model.predict(x_test)
# Out:
# the train accuracy of our model is : 79.24%

# %%
from sklearn.metrics import r2_score
print(f"r2 for our model is {r2_score(y_test,y_pred)*100:.2f}")
# Out:
# r2 for our model is 79.24

# %%
 # implementing in regularized models
# 1-> ridge
from sklearn.linear_model import Ridge
# we learnt about something called as lemda here it is named as alpha
ridge_model = Ridge(alpha=0.5)
ridge_model
# Out:
# Ridge(alpha=0.5)

# %%
ridge_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.5)

# %%
for i , col in enumerate(x_train.columns):
    print(f"for {col} the coefficient value if ridge model is {ridge_model.coef_[i]:.5f}")
# Out:
# for cylinders the coefficient value if ridge model is -0.26420
# for displacement the coefficient value if ridge model is 0.01802
# for horsepower the coefficient value if ridge model is -0.00001
# for weight the coefficient value if ridge model is -0.00751
# for acceleration the coefficient value if ridge model is 0.13638
# for model_year the coefficient value if ridge model is 0.77240
# for origin the coefficient value if ridge model is 1.54676

# %%
y_pred_ridge = ridge_model.predict(x_test)
print(f"r2 for our ridge_model is {r2_score(y_test,y_pred_ridge)*100:.2f}")
# Out:
# r2 for our ridge_model is 79.25

# %%
from sklearn.linear_model import Lasso
lasso_model = Lasso(alpha = 0.5)
lasso_model
# Out:
# Lasso(alpha=0.5)

# %%
lasso_model.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.5)

# %%
for i , col in enumerate(x_train.columns):
    print(f"for {col} the coefficient value if lasso model is {lasso_model.coef_[i]:.5f}")
# Out:
# for cylinders the coefficient value if lasso model is -0.00000
# for displacement the coefficient value if lasso model is -0.00133
# for horsepower the coefficient value if lasso model is -0.00381
# for weight the coefficient value if lasso model is -0.00659
# for acceleration the coefficient value if lasso model is 0.00000
# for model_year the coefficient value if lasso model is 0.67548
# for origin the coefficient value if lasso model is 0.12910

# %%
y_pred_lasso = ridge_model.predict(x_test)
print(f"r2 for our lasso_model is {r2_score(y_test,y_pred_lasso)*100:.2f}")
# Out:
# r2 for our lasso_model is 79.25

# %%
from sklearn.linear_model import ElasticNet
elastic_model = ElasticNet(alpha = 1 , l1_ratio = 0.5)
elastic_model
# Out:
# ElasticNet(alpha=1)

# %%
elastic_model.fit(x_train ,y_train)
# Out:
# ElasticNet(alpha=1)

# %%
y_pred_elastic_net = elastic_model.predict(x_test)
print(f"r2 for our elastic_net_model is {r2_score(y_test,y_pred_elastic_net)*100:.2f}")
# Out:
# r2 for our elastic_net_model is 78.72

# %%
for i , col in enumerate(x_train.columns):
    print(f"for {col} the coefficient value if elastic net model is {elastic_model.coef_[i]:.5f}")
# Out:
# for cylinders the coefficient value if elastic net model is -0.00000
# for displacement the coefficient value if elastic net model is -0.00253
# for horsepower the coefficient value if elastic net model is -0.00463
# for weight the coefficient value if elastic net model is -0.00650
# for acceleration the coefficient value if elastic net model is 0.00000
# for model_year the coefficient value if elastic net model is 0.64355
# for origin the coefficient value if elastic net model is 0.04143

# %%
#  regularization with lasso
from sklearn.linear_model import LassoCV
lasso_model_CV = LassoCV(cv =  5, verbose=2)
lasso_model_CV.fit(x_train,y_train)
# Out:
# Path: 000 out of 100
# Path: 001 out of 100
# Path: 002 out of 100
# Path: 003 out of 100
# Path: 004 out of 100
# Path: 005 out of 100
# Path: 006 out of 100
# Path: 007 out of 100
# Path: 008 out of 100
# Path: 009 out of 100
# Path: 010 out of 100
# Path: 011 out of 100
# Path: 012 out of 100
# Path: 013 out of 100
# Path: 014 out of 100
# Path: 015 out of 100
# Path: 016 out of 100
# Path: 017 out of 100
# Path: 018 out of 100
# Path: 019 out of 100
# Path: 020 out of 100
# Path: 021 out of 100
# Path: 022 out of 100
# Path: 023 out of 100
# Path: 024 out of 100
# Path: 025 out of 100
# Path: 026 out of 100
# Path: 027 out of 100
# Path: 028 out of 100
# Path: 029 out of 100
# Path: 030 out of 100
# Path: 031 out of 100
# Path: 032 out of 100
# Path: 033 out of 100
# Path: 034 out of 100
# Path: 035 out of 100
# Path: 036 out of 100
# Path: 037 out of 100
# Path: 038 out of 100
# Path: 039 out of 100
# Path: 040 out of 100
# Path: 041 out of 100
# Path: 042 out of 100
# Path: 043 out of 100
# Path: 044 out of 100
# Path: 045 out of 100
# Path: 046 out of 100
# Path: 047 out of 100
# Path: 048 out of 100
# Path: 049 out of 100
# Path: 050 out of 100
# Path: 051 out of 100
# Path: 052 out of 100
# Path: 053 out of 100
# Path: 054 out of 100
# Path: 055 out of 100
# Path: 056 out of 100
# Path: 057 out of 100
# Path: 058 out of 100
# Path: 059 out of 100
# Path: 060 out of 100
# Path: 061 out of 100
# Path: 062 out of 100
# Path: 063 out of 100
# Path: 064 out of 100
# Path: 065 out of 100
# Path: 066 out of 100
# Path: 067 out of 100
# Path: 068 out of 100
# Path: 069 out of 100
# Path: 045 out of 100
# Path: 046 out of 100
# Path: 047 out of 100
# Path: 048 out of 100
# Path: 049 out of 100
# Path: 050 out of 100
# Path: 051 out of 100
# Path: 052 out of 100
# Path: 053 out of 100
# Path: 054 out of 100
# Path: 055 out of 100
# Path: 056 out of 100
# Path: 057 out of 100
# Path: 058 out of 100
# Path: 059 out of 100
# Path: 060 out of 100
# Path: 061 out of 100
# Path: 062 out of 100
# Path: 063 out of 100
# Path: 064 out of 100
# Path: 065 out of 100
# Path: 066 out of 100
# Path: 067 out of 100
# Path: 068 out of 100
# Path: 069 out of 100
# Path: 070 out of 100
# Path: 071 out of 100
# Path: 072 out of 100
# Path: 073 out of 100
# Path: 074 out of 100
# Path: 075 out of 100
# Path: 076 out of 100
# Path: 077 out of 100
# Path: 078 out of 100
# Path: 079 out of 100
# Path: 080 out of 100
# Path: 081 out of 100
# Path: 082 out of 100
# Path: 083 out of 100
# Path: 084 out of 100
# Path: 085 out of 100
# Path: 086 out of 100
# Path: 087 out of 100
# Path: 088 out of 100
# Path: 089 out of 100
# Path: 090 out of 100
# Path: 091 out of 100
# Path: 092 out of 100
# Path: 093 out of 100
# Path: 094 out of 100
# Path: 095 out of 100
# Path: 096 out of 100
# Path: 097 out of 100
# Path: 098 out of 100
# Path: 099 out of 100
# LassoCV(cv=5, verbose=2)

# %%
for i , col in enumerate(x_train.columns):
    print(f"for {col} the coefficient value if elastic net model {lasso_model_CV.coef_[i]:.5f}")
# Out:
# for cylinders the coefficient value if elastic net model -0.00000
# for displacement the coefficient value if elastic net model -0.00857
# for horsepower the coefficient value if elastic net model -0.00728
# for weight the coefficient value if elastic net model -0.00619
# for acceleration the coefficient value if elastic net model 0.00000
# for model_year the coefficient value if elastic net model 0.25541
# for origin the coefficient value if elastic net model 0.00000

# %%
y_pred_lasso_cv = lasso_model_CV.predict(x_test)
print(f"r2 for our lasso_model_CV is {r2_score(y_test,y_pred_lasso_cv)*100:.2f}")
# Out:
# r2 for our lasso_model_CV is 72.24

# %%
#  regularization with lasso
from sklearn.linear_model import RidgeCV
ridge_model_CV = RidgeCV(cv =  5)
ridge_model_CV.fit(x_train,y_train)

for i , col in enumerate(x_train.columns):
    print(f"for {col} the coefficient value if elastic net model {ridge_model_CV.coef_[i]:.5f}")
# Out:
# for cylinders the coefficient value if elastic net model -0.22905
# for displacement the coefficient value if elastic net model 0.01633
# for horsepower the coefficient value if elastic net model 0.00072
# for weight the coefficient value if elastic net model -0.00747
# for acceleration the coefficient value if elastic net model 0.13623
# for model_year the coefficient value if elastic net model 0.76612
# for origin the coefficient value if elastic net model 1.42576

# %%
y_pred_ridge_cv = ridge_model_CV.predict(x_test)
print(f"r2 for our ridge_model_CV is {r2_score(y_test,y_pred_ridge_cv)*100:.2f}")
# Out:
# r2 for our ridge_model_CV is 79.31

# %%
#  regularization with lasso
from sklearn.linear_model import ElasticNetCV
elastic_net_model_CV = ElasticNetCV(cv =  5)
elastic_net_model_CV.fit(x_train,y_train)

for i , col in enumerate(x_train.columns):
    print(f"for {col} the coefficient value if elastic net model {elastic_net_model_CV.coef_[i]:.5f}")
# Out:
# for cylinders the coefficient value if elastic net model -0.00000
# for displacement the coefficient value if elastic net model -0.00982
# for horsepower the coefficient value if elastic net model -0.01077
# for weight the coefficient value if elastic net model -0.00601
# for acceleration the coefficient value if elastic net model 0.00000
# for model_year the coefficient value if elastic net model 0.17215
# for origin the coefficient value if elastic net model 0.00000

# %%
y_pred_elastic_cv = ridge_model_CV.predict(x_test)
print(f"r2 for our ridge_model_CV is {r2_score(y_test,y_pred_elastic_cv)*100:.2f}")
# Out:
# r2 for our ridge_model_CV is 79.31

# %%
from sklearn.model_selection import GridSearchCV , RandomizedSearchCV

# %%
lasso =Lasso()
ridge = Ridge()
lastic_net = ElasticNet()

# %%
# grid search cv
param_grid = {'alpha' : [ 0.001 , 0.01 , 0.1 , 0.5 , 1] }

# %%
#  grid search using lasso 
grid_search = GridSearchCV(estimator= lasso , param_grid= param_grid , cv = 5 , scoring = 'r2' , verbose = 2)

# %%
grid_search
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 0.5, 1]}, scoring='r2',
#              verbose=2)

# %%
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.5; total time=   0.0s
# [CV] END ..........................................alpha=0.5; total time=   0.0s
# [CV] END ..........................................alpha=0.5; total time=   0.0s
# [CV] END ..........................................alpha=0.5; total time=   0.0s
# [CV] END ..........................................alpha=0.5; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 0.5, 1]}, scoring='r2',
#              verbose=2)

# %%
grid_search.best_params_['alpha']
# Out:
# 0.1

# %%
grid_search.best_score_
# Out:
# 0.8196572002881158

# %%
y_pred_grid = grid_search.best_estimator_.predict(x_test)

# %%
print(f"r2 score for grid search cv is {r2_score(y_pred_grid , y_test)*100:.2f}")
# Out:
# r2 score for grid search cv is 77.34

# %%
#  grid search using Ridge 
grid_search = GridSearchCV(estimator= ridge , param_grid= param_grid , cv = 5 , scoring = 'r2' , verbose = 2)

# %%
grid_search
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 0.5, 1]}, scoring='r2',
#              verbose=2)

# %%
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.5; total time=   0.0s
# [CV] END ..........................................alpha=0.5; total time=   0.0s
# [CV] END ..........................................alpha=0.5; total time=   0.0s
# [CV] END ..........................................alpha=0.5; total time=   0.0s
# [CV] END ..........................................alpha=0.5; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 0.5, 1]}, scoring='r2',
#              verbose=2)

# %%
grid_search.best_params_['alpha']
# Out:
# 1

# %%
grid_search.best_score_
# Out:
# 0.8193823773840696

# %%
y_pred_grid_ridge = grid_search.best_estimator_.predict(x_test)

# %%
print(f"r2 score for grid search cv is {r2_score(y_pred_grid_ridge , y_test)*100:.2f}")
# Out:
# r2 score for grid search cv is 77.54

# %%
param_dist = {'alpha' : [ 0.001 , 0.01 , 0.1 , 1 , 100] }
random_search = RandomizedSearchCV(estimator= lasso , param_distributions=param_dist , n_iter= 3 , cv = 5 , scoring = 'r2',verbose = 2 )

# %%
random_search
# Out:
# RandomizedSearchCV(cv=5, estimator=Lasso(), n_iter=3,
#                    param_distributions={'alpha': [0.001, 0.01, 0.1, 1, 100]},
#                    scoring='r2', verbose=2)

# %%
random_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# RandomizedSearchCV(cv=5, estimator=Lasso(), n_iter=3,
#                    param_distributions={'alpha': [0.001, 0.01, 0.1, 1, 100]},
#                    scoring='r2', verbose=2)

# %%
random_search.best_params_['alpha']
# Out:
# 0.001

# %%
random_search.best_score_
# Out:
# 0.8193493145705133

# %%
y_pred_random = random_search.best_estimator_.predict(x_test)

# %%
print(f"r2 for randomised search cv is {r2_score(y_pred_random , y_test)*100:.2f}")
# Out:
# r2 for randomised search cv is 77.54
