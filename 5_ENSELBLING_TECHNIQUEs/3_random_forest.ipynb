# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# time is target varibale .. when he/she is visiting

# %%
df.time.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
# sex           category converting it to integert using encoding
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder
# Out:
# LabelEncoder()

# %%
df['time'] = encoder.fit_transform(df['time'])

# %%
df['time']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 239    0
# 240    0
# 241    0
# 242    0
# 243    0
# Name: time, Length: 244, dtype: int32

# %%
from sklearn.model_selection import train_test_split 
x = df.drop('time',axis =1 )
y = df['time']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape , x_test.shape
# Out:
# ((170, 6), (74, 6))

# %%
from sklearn.impute import SimpleImputer # for missing value treatement
from sklearn.preprocessing import StandardScaler # for scaling everything ( for numerical col )
from sklearn.preprocessing import OneHotEncoder # for encoding 
from sklearn.pipeline import Pipeline # a sequence of data transformer
from sklearn.compose import ColumnTransformer # groups all pipeline step for each of the columns

# %%
df.sample(1)
# Out:
#      total_bill  tip     sex smoker  day  time  size
# 169       10.63  2.0  Female    Yes  Sat     0     2

# %%
cat_col = ['sex','smoker','day']
num_col = ['total_bill' , 'tip','size']

# %%
df[num_col]
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
df[cat_col]
# Out:
#         sex smoker   day
# 0    Female     No   Sun
# 1      Male     No   Sun
# 2      Male     No   Sun
# 3      Male     No   Sun
# 4    Female     No   Sun
# ..      ...    ...   ...
# 239    Male     No   Sat
# 240  Female    Yes   Sat
# 241    Male    Yes   Sat
# 242    Male     No   Sat
# 243  Female     No  Thur
#
# [244 rows x 3 columns]

# %%
# feature enginering automation using pipeline and transformers

# %%
cat_pipeline = Pipeline(steps = [
                                ('Imputation' , SimpleImputer(strategy= 'most_frequent')) , 
                                ('OneHotEncoding',OneHotEncoder()) ,
                                ] )
num_pipeline = Pipeline(steps = [
                                ('Imputation' , SimpleImputer(strategy= 'median')) ,
                                ('Scaling' , StandardScaler()) ] )

# %%
col_transformer = ColumnTransformer([
                                    ("num_pipeline" , num_pipeline , num_col),
                                    ("cat_pipeline" , cat_pipeline , cat_col)
                                    ])

# %%
col_transformer
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('Imputation',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('Scaling',
#                                                   StandardScaler())]),
#                                  ['total_bill', 'tip', 'size']),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('Imputation',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('OneHotEncoding',
#                                                   OneHotEncoder())]),
#                                  ['sex', 'smoker', 'day'])])

# %%
x_train = col_transformer.fit_transform(x_train)
x_test = col_transformer.fit_transform(x_test)

# %%
# now data is ready now lets make multiple models

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# %%
models = {"Support vector classifier" : SVC(),
          "Decision Tree Classifier" : DecisionTreeClassifier(),
          "Logistic Regression" : LogisticRegression()
         }

# %%
from sklearn.metrics import accuracy_score

def models_evaluation(x_train,x_test,y_train,y_test , models):
    evaluation = {}
    for i in range(len(models)):
        m = list(models.values())[i]
        m.fit(x_train,y_train)
        y_pred = m.predict(x_test)
        m_score = round(accuracy_score(y_test,y_pred)*100,2)
        evaluation[list(models.values())[i]] = m_score

    return evaluation

# %%
models_evaluation(x_train,x_test,y_train,y_test,models)
# Out:
# {SVC(): 95.95, DecisionTreeClassifier(): 97.3, LogisticRegression(): 95.95}

# %%
from sklearn.ensemble import RandomForestClassifier
RF  = RandomForestClassifier(n_estimators=10 ,criterion='accuracy_score') 
RF
# Out:
# RandomForestClassifier(criterion='accuracy_score', n_estimators=10)

# %%
from sklearn.model_selection import GridSearchCV
param =  { 'max_depth' : [1,4,8,10,None],
          'n_estimators' : [10,20,30,100,None],
          'criterion' : ['gini','entropy']}

# %%
clf = GridSearchCV(estimator = RF , param_grid  = param ,cv = 5 , verbose= 2, scoring = 'accuracy' )
clf
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(criterion='accuracy_score',
#                                               n_estimators=10),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 4, 8, 10, None],
#                          'n_estimators': [10, 20, 30, 100, None]},
#              scoring='accuracy', verbose=2)

# %%
clf.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END .......criterion=gini, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=1, n_estimators=30; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=1, n_estimators=30; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=1, n_estimators=30; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=1, n_estimators=30; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=1, n_estimators=30; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=1, n_estimators=100; total time=   0.1s
# [CV] END ......criterion=gini, max_depth=1, n_estimators=100; total time=   0.1s
# [CV] END ......criterion=gini, max_depth=1, n_estimators=100; total time=   0.1s
# [CV] END ......criterion=gini, max_depth=1, n_estimators=100; total time=   0.1s
# [CV] END ......criterion=gini, max_depth=1, n_estimators=100; total time=   0.1s
# [CV] END .....criterion=gini, max_depth=1, n_estimators=None; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=1, n_estimators=None; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=1, n_estimators=None; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=1, n_estimators=None; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=1, n_estimators=None; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=30; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=30; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=30; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=30; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=4, n_estimators=30; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END ......criterion=gini, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END ......criterion=gini, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END ......criterion=gini, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END ......criterion=gini, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END .....criterion=gini, max_depth=4, n_estimators=None; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=4, n_estimators=None; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=4, n_estimators=None; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=4, n_estimators=None; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=4, n_estimators=None; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=10; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=30; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=30; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=30; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=30; total time=   0.0s
# [CV] END .......criterion=gini, max_depth=8, n_estimators=30; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END ......criterion=gini, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END ......criterion=gini, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END ......criterion=gini, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END ......criterion=gini, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END .....criterion=gini, max_depth=8, n_estimators=None; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=8, n_estimators=None; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=8, n_estimators=None; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=8, n_estimators=None; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=8, n_estimators=None; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=20; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=20; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=20; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=20; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=20; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=30; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=30; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=30; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=30; total time=   0.0s
# [CV] END ......criterion=gini, max_depth=10, n_estimators=30; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END ....criterion=gini, max_depth=10, n_estimators=None; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=10, n_estimators=None; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=10, n_estimators=None; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=10, n_estimators=None; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=10, n_estimators=None; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=gini, max_depth=None, n_estimators=30; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END ..criterion=gini, max_depth=None, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=None, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=None, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=None, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=gini, max_depth=None, n_estimators=None; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=1, n_estimators=30; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=1, n_estimators=100; total time=   0.1s
# [CV] END ...criterion=entropy, max_depth=1, n_estimators=100; total time=   0.1s
# [CV] END ...criterion=entropy, max_depth=1, n_estimators=100; total time=   0.1s
# [CV] END ...criterion=entropy, max_depth=1, n_estimators=100; total time=   0.1s
# [CV] END ...criterion=entropy, max_depth=1, n_estimators=100; total time=   0.1s
# [CV] END ..criterion=entropy, max_depth=1, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=1, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=1, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=1, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=1, n_estimators=None; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=4, n_estimators=30; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END ...criterion=entropy, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END ...criterion=entropy, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END ...criterion=entropy, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END ...criterion=entropy, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END ..criterion=entropy, max_depth=4, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=4, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=4, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=4, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=4, n_estimators=None; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=10; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=30; total time=   0.0s
# [CV] END ....criterion=entropy, max_depth=8, n_estimators=30; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END ...criterion=entropy, max_depth=8, n_estimators=100; total time=   0.2s
# [CV] END ...criterion=entropy, max_depth=8, n_estimators=100; total time=   0.2s
# [CV] END ...criterion=entropy, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END ...criterion=entropy, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END ..criterion=entropy, max_depth=8, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=8, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=8, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=8, n_estimators=None; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=8, n_estimators=None; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=10; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=20; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=20; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=20; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=20; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=20; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=30; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=30; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=30; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=30; total time=   0.0s
# [CV] END ...criterion=entropy, max_depth=10, n_estimators=30; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.1s
# [CV] END .criterion=entropy, max_depth=10, n_estimators=None; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=10, n_estimators=None; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=10, n_estimators=None; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=10, n_estimators=None; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=10, n_estimators=None; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=10; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=20; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=20; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=20; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=20; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=20; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=30; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=30; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=30; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=30; total time=   0.0s
# [CV] END .criterion=entropy, max_depth=None, n_estimators=30; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, max_depth=None, n_estimators=None; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=None; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=None; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=None; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=None; total time=   0.0s
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(criterion='accuracy_score',
#                                               n_estimators=10),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 4, 8, 10, None],
#                          'n_estimators': [10, 20, 30, 100, None]},
#              scoring='accuracy', verbose=2)

# %%
clf.best_estimator_
# Out:
# RandomForestClassifier(max_depth=4, n_estimators=10)

# %%
y_pred = clf.best_estimator_.predict(x_test)

# %%
score = round(accuracy_score(y_test,y_pred)*100,2)

# %%
print("final model score is :", score)
# Out:
# final model score is : 95.95

# %%
# final model 
final_model = clf.best_estimator_

# %%
final_model
# Out:
# RandomForestClassifier(max_depth=4, n_estimators=10)

# %%
from sklearn.ensemble import RandomForestClassifier
RF2  = RandomForestClassifier(n_estimators=10 ,oob_score=True) 
RF2
# Out:
# RandomForestClassifier(n_estimators=10, oob_score=True)

# %%
RF2.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10, oob_score=True)

# %%
RF2.oob_score_*100
# Out:
# 95.88235294117648
